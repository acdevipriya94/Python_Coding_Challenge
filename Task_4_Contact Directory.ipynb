# %%
contact = [["Devi" , "9876543214" , "devi@gmai.com"] , ["Iyal" , "3216549875" , "iyal@gmail.com"]]
name = input("Enter the name : ")
mob = input("Enter Mobile number : ")
email = input("Enter email address : ")
contact.append([name, mob, email])
# Out:
# Enter the name : Udhaya
# Enter Mobile number : 8527419632
# Enter email address : udhaya@gmail.com

# %%
contact
# Out:
# [['Devi', '9876543214', 'devi@gmai.com'],
#  ['Iyal', '3216549875', 'iyal@gmail.com'],
#  ['Udhaya', '8527419632', 'udhaya@gmail.com']]

# %%
contact.pop()
# Out:
# ['Udhaya', '8527419632', 'udhaya@gmail.com']

# %%
name = input("Enter the name : ")
mob = input("Enter Mobile number : ")
email = input("Enter email address : ")
contact.append([name, mob, email])
# Out:
# Enter the name : Udhaya
# Enter Mobile number : 8527419635
# Enter email address : udhaya@gmail.com

# %%
contact.sort()
contact
# Out:
# [['Devi', '9876543214', 'devi@gmai.com'],
#  ['Iyal', '3216549875', 'iyal@gmail.com'],
#  ['Udhaya', '8527419635', 'udhaya@gmail.com']]

# %%
print(contact)
for c in contact:
  print(c)
# Out:
# [['Devi', '9876543214', 'devi@gmai.com'], ['Iyal', '3216549875', 'iyal@gmail.com'], ['Udhaya', '8527419635', 'udhaya@gmail.com']]
# ['Devi', '9876543214', 'devi@gmai.com']
# ['Iyal', '3216549875', 'iyal@gmail.com']
# ['Udhaya', '8527419635', 'udhaya@gmail.com']
