# %%
feedback = input("Enter Your Feedback : ")
words = feedback.split()
print(f"Count of Words in Feedback : {len(words)}")
print(f"No of times word Data appear : {feedback.lower().count("data")} ")
# Out:
# Enter Your Feedback : Data looks Impressive, love to work on this data
# Count of Words in Feedback : 9
# No of times word Data appear : 2

# %%
print(f"First 5 : {feedback[:5]}")
# Out:
# First 5 : Data

# %%
print(f"last 5 : {feedback[-5:]}")
# Out:
# last 5 :  data

# %%
print(f"Reverse Feedback : {feedback[::-1]}")
# Out:
# Reverse Feedback : atad siht no krow ot evol ,evisserpmI skool ataD
