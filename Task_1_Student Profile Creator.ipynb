# %%
stu_name = "Devi"
stu_age = 15
subjects = ['Tam' , 'Eng' , 'Mat']

# %%
print(f"Student Details")
print(f"Student Name is : {stu_name}")
print(f"Student Age is : {stu_age}")
print(f"Favourite Subjects : {subjects}")
# Out:
# Student Details
# Student Name is : Devi
# Student Age is : 15
# Favourite Subjects : ['Tam', 'Eng', 'Mat']

# %%
subjects.append("Computer")
subjects.pop()
# Out:
# 'Computer'

# %%
subjects
# Out:
# ['Tam', 'Eng', 'Mat', 'Computer', 'Computer']

# %%
subjects.pop()
# Out:
# 'Computer'

# %%
subjects
# Out:
# ['Tam', 'Eng', 'Mat', 'Computer']
